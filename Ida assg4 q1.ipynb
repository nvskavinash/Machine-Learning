# %%
import pandas as pd
import numpy as np
import sklearn
from openpyxl import load_workbook
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier,export_graphviz
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import accuracy_score,recall_score,precision_score
from sklearn.metrics import confusion_matrix
import seaborn as sns
from scipy import misc
import graphviz
import pydotplus
from sklearn.datasets.samples_generator import make_blobs
import io
import matplotlib.patches as mpatches
import random
import math
import xlrd
from itertools import product
from sklearn.model_selection import KFold 
from sklearn.cross_validation import cross_val_score
from xlrd import open_workbook
from scipy import misc
from PIL import Image
import matplotlib.pyplot as plt 
import random
# %matplotlib inline

# %%
from statsmodels.regression.linear_model import OLS
from statsmodels.tools import add_constant
from sklearn import datasets

# %%
data=pd.read_csv('./winequality-white.csv')

# %%
data
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.0             0.270         0.36           20.70      0.045
# 1               6.3             0.300         0.34            1.60      0.049
# 2               8.1             0.280         0.40            6.90      0.050
# 3               7.2             0.230         0.32            8.50      0.058
# 4               7.2             0.230         0.32            8.50      0.058
# 5               8.1             0.280         0.40            6.90      0.050
# 6               6.2             0.320         0.16            7.00      0.045
# 7               7.0             0.270         0.36           20.70      0.045
# 8               6.3             0.300         0.34            1.60      0.049
# 9               8.1             0.220         0.43            1.50      0.044
# 10              8.1             0.270         0.41            1.45      0.033
# 11              8.6             0.230         0.40            4.20      0.035
# 12              7.9             0.180         0.37            1.20      0.040
# 13              6.6             0.160         0.40            1.50      0.044
# 14              8.3             0.420         0.62           19.25      0.040
# 15              6.6             0.170         0.38            1.50      0.032
# 16              6.3             0.480         0.04            1.10      0.046
# 17              6.2             0.660         0.48            1.20      0.029
# 18              7.4             0.340         0.42            1.10      0.033
# 19              6.5             0.310         0.14            7.50      0.044
# 20              6.2             0.660         0.48            1.20      0.029
# 21              6.4             0.310         0.38            2.90      0.038
# 22              6.8             0.260         0.42            1.70      0.049
# 23              7.6             0.670         0.14            1.50      0.074
# 24              6.6             0.270         0.41            1.30      0.052
# 25              7.0             0.250         0.32            9.00      0.046
# 26              6.9             0.240         0.35            1.00      0.052
# 27              7.0             0.280         0.39            8.70      0.051
# 28              7.4             0.270         0.48            1.10      0.047
# 29              7.2             0.320         0.36            2.00      0.033
# ...             ...               ...          ...             ...        ...
# 4868            5.8             0.230         0.31            4.50      0.046
# 4869            6.6             0.240         0.33           10.10      0.032
# 4870            6.1             0.320         0.28            6.60      0.021
# 4871            5.0             0.200         0.40            1.90      0.015
# 4872            6.0             0.420         0.41           12.40      0.032
# 4873            5.7             0.210         0.32            1.60      0.030
# 4874            5.6             0.200         0.36            2.50      0.048
# 4875            7.4             0.220         0.26            1.20      0.035
# 4876            6.2             0.380         0.42            2.50      0.038
# 4877            5.9             0.540         0.00            0.80      0.032
# 4878            6.2             0.530         0.02            0.90      0.035
# 4879            6.6             0.340         0.40            8.10      0.046
# 4880            6.6             0.340         0.40            8.10      0.046
# 4881            5.0             0.235         0.27           11.75      0.030
# 4882            5.5             0.320         0.13            1.30      0.037
# 4883            4.9             0.470         0.17            1.90      0.035
# 4884            6.5             0.330         0.38            8.30      0.048
# 4885            6.6             0.340         0.40            8.10      0.046
# 4886            6.2             0.210         0.28            5.70      0.028
# 4887            6.2             0.410         0.22            1.90      0.023
# 4888            6.8             0.220         0.36            1.20      0.052
# 4889            4.9             0.235         0.27           11.75      0.030
# 4890            6.1             0.340         0.29            2.20      0.036
# 4891            5.7             0.210         0.32            0.90      0.038
# 4892            6.5             0.230         0.38            1.30      0.032
# 4893            6.2             0.210         0.29            1.60      0.039
# 4894            6.6             0.320         0.36            8.00      0.047
# 4895            6.5             0.240         0.19            1.20      0.041
# 4896            5.5             0.290         0.30            1.10      0.022
# 4897            6.0             0.210         0.38            0.80      0.020
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# 5                    30.0                  97.0  0.99510  3.26       0.44
# 6                    30.0                 136.0  0.99490  3.18       0.47
# 7                    45.0                 170.0  1.00100  3.00       0.45
# 8                    14.0                 132.0  0.99400  3.30       0.49
# 9                    28.0                 129.0  0.99380  3.22       0.45
# 10                   11.0                  63.0  0.99080  2.99       0.56
# 11                   17.0                 109.0  0.99470  3.14       0.53
# 12                   16.0                  75.0  0.99200  3.18       0.63
# 13                   48.0                 143.0  0.99120  3.54       0.52
# 14                   41.0                 172.0  1.00020  2.98       0.67
# 15                   28.0                 112.0  0.99140  3.25       0.55
# 16                   30.0                  99.0  0.99280  3.24       0.36
# 17                   29.0                  75.0  0.98920  3.33       0.39
# 18                   17.0                 171.0  0.99170  3.12       0.53
# 19                   34.0                 133.0  0.99550  3.22       0.50
# 20                   29.0                  75.0  0.98920  3.33       0.39
# 21                   19.0                 102.0  0.99120  3.17       0.35
# 22                   41.0                 122.0  0.99300  3.47       0.48
# 23                   25.0                 168.0  0.99370  3.05       0.51
# 24                   16.0                 142.0  0.99510  3.42       0.47
# 25                   56.0                 245.0  0.99550  3.25       0.50
# 26                   35.0                 146.0  0.99300  3.45       0.44
# 27                   32.0                 141.0  0.99610  3.38       0.53
# 28                   17.0                 132.0  0.99140  3.19       0.49
# 29                   37.0                 114.0  0.99060  3.10       0.71
# ...                   ...                   ...      ...   ...        ...
# 4868                 42.0                 124.0  0.99324  3.31       0.64
# 4869                  8.0                  81.0  0.99626  3.19       0.51
# 4870                 29.0                 132.0  0.99188  3.15       0.36
# 4871                 20.0                  98.0  0.98970  3.37       0.55
# 4872                 50.0                 179.0  0.99622  3.14       0.60
# 4873                 33.0                 122.0  0.99044  3.33       0.52
# 4874                 16.0                 125.0  0.99282  3.49       0.49
# 4875                 18.0                  97.0  0.99245  3.12       0.41
# 4876                 34.0                 117.0  0.99132  3.36       0.59
# 4877                 12.0                  82.0  0.99286  3.25       0.36
# 4878                  6.0                  81.0  0.99234  3.24       0.35
# 4879                 68.0                 170.0  0.99494  3.15       0.50
# 4880                 68.0                 170.0  0.99494  3.15       0.50
# 4881                 34.0                 118.0  0.99540  3.07       0.50
# 4882                 45.0                 156.0  0.99184  3.26       0.38
# 4883                 60.0                 148.0  0.98964  3.27       0.35
# 4884                 68.0                 174.0  0.99492  3.14       0.50
# 4885                 68.0                 170.0  0.99494  3.15       0.50
# 4886                 45.0                 121.0  0.99168  3.21       1.08
# 4887                  5.0                  56.0  0.98928  3.04       0.79
# 4888                 38.0                 127.0  0.99330  3.04       0.54
# 4889                 34.0                 118.0  0.99540  3.07       0.50
# 4890                 25.0                 100.0  0.98938  3.06       0.44
# 4891                 38.0                 121.0  0.99074  3.24       0.46
# 4892                 29.0                 112.0  0.99298  3.29       0.54
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#         alcohol  quality
# 0      8.800000        6
# 1      9.500000        6
# 2     10.100000        6
# 3      9.900000        6
# 4      9.900000        6
# 5     10.100000        6
# 6      9.600000        6
# 7      8.800000        6
# 8      9.500000        6
# 9     11.000000        6
# 10    12.000000        5
# 11     9.700000        5
# 12    10.800000        5
# 13    12.400000        7
# 14     9.700000        5
# 15    11.400000        7
# 16     9.600000        6
# 17    12.800000        8
# 18    11.300000        6
# 19     9.500000        5
# 20    12.800000        8
# 21    11.000000        7
# 22    10.500000        8
# 23     9.300000        5
# 24    10.000000        6
# 25    10.400000        6
# 26    10.000000        6
# 27    10.500000        6
# 28    11.600000        6
# 29    12.300000        7
# ...         ...      ...
# 4868  10.800000        6
# 4869   9.800000        6
# 4870  11.450000        7
# 4871  12.050000        6
# 4872   9.700000        5
# 4873  11.900000        6
# 4874  10.000000        6
# 4875   9.700000        6
# 4876  11.600000        7
# 4877   8.800000        5
# 4878   9.500000        4
# 4879   9.533333        6
# 4880   9.533333        6
# 4881   9.400000        6
# 4882  10.700000        5
# 4883  11.500000        6
# 4884   9.600000        5
# 4885   9.550000        6
# 4886  12.150000        7
# 4887  13.000000        7
# 4888   9.200000        5
# 4889   9.400000        6
# 4890  11.800000        6
# 4891  10.600000        6
# 4892   9.700000        5
# 4893  11.200000        6
# 4894   9.600000        5
# 4895   9.400000        6
# 4896  12.800000        7
# 4897  11.800000        6
#
# [4898 rows x 12 columns]

# %%
#iteration 1
for column in data:
    if str(column) != 'quality':
        print('Parameters, R^2 and AIC values for model with '+ column +':\n')
        lmwhite = smf.ols(formula='quality'+ '~' + column , data=data).fit()
        print('Parameters:\n')
        print(lmwhite.params)
        print('R Squared values:  ')
        print(lmwhite.rsquared)
        print('AIC Value:   ')
        print(lmwhite.aic)
        print('\n')
# Out:
# Parameters, R^2 and AIC values for model with fixed_acidity:
#
# Parameters:
#
# Intercept        6.695610
# fixed_acidity   -0.119289
# dtype: float64
# R Squared values:
# 0.012919239085696477
# AIC Value:
# 12649.542674671115
#
#
# Parameters, R^2 and AIC values for model with volatile_acidity:
#
# Parameters:
#
# Intercept           6.353965
# volatile_acidity   -1.710947
# dtype: float64
# R Squared values:
# 0.0379170346254607
# AIC Value:
# 12523.903238229133
#
#
# Parameters, R^2 and AIC values for model with citric_acid:
#
# Parameters:
#
# Intercept      5.900432
# citric_acid   -0.067393
# dtype: float64
# R Squared values:
# 8.480735490945523e-05
# AIC Value:
# 12712.818013276958
#
#
# Parameters, R^2 and AIC values for model with residual_sugar:
#
# Parameters:
#
# Intercept         5.986806
# residual_sugar   -0.017038
# dtype: float64
# R Squared values:
# 0.009521237537144067
# AIC Value:
# 12666.37496494396
#
#
# Parameters, R^2 and AIC values for model with chlorides:
#
# Parameters:
#
# Intercept    6.267432
# chlorides   -8.509991
# dtype: float64
# R Squared values:
# 0.04407245689956285
# AIC Value:
# 12492.465076996094
#
#
# Parameters, R^2 and AIC values for model with free_sulfur_dioxide:
#
# Parameters:
#
# Intercept              5.862910
# free_sulfur_dioxide    0.000425
# dtype: float64
# R Squared values:
# 6.655405919020474e-05
# AIC Value:
# 12712.907424686111
#
#
# Parameters, R^2 and AIC values for model with total_sulfur_dioxide:
#
# Parameters:
#
# Intercept               6.381741
# total_sulfur_dioxide   -0.003641
# dtype: float64
# R Squared values:
# 0.030533095213563177
# AIC Value:
# 12561.351623049086
#
#
# Parameters, R^2 and AIC values for model with density:
#
# Parameters:
#
# Intercept    96.277145
# density     -90.942400
# dtype: float64
# R Squared values:
# 0.094324729225155
# AIC Value:
# 12227.96672220093
#
#
# Parameters, R^2 and AIC values for model with pH:
#
# Parameters:
#
# Intercept    4.018659
# pH           0.583154
# dtype: float64
# R Squared values:
# 0.009885777194779233
# AIC Value:
# 12664.571954152203
#
#
# Parameters, R^2 and AIC values for model with sulphates:
#
# Parameters:
#
# Intercept    5.673863
# sulphates    0.416551
# dtype: float64
# R Squared values:
# 0.002881314493483722
# AIC Value:
# 12699.10036825579
#
#
# Parameters, R^2 and AIC values for model with alcohol:
#
# Parameters:
#
# Intercept    2.582009
# alcohol      0.313469
# dtype: float64
# R Squared values:
# 0.18972533274950443
# AIC Value:
# 11682.782413522953

# %%
#iteration 2
import pandas as pd
import statsmodels.formula.api as smf

data = pd.read_csv('winequality-white.csv')
data1 = data.iloc[:,data.columns!='quality']


for column in data1:
    if str(column) != 'alcohol':
        print('Parameters, R^2 and AIC values for model with '+ 'alcohol' + ' and '+column +':\n')
        lmwhite = smf.ols(formula='quality'+ '~' + 'alcohol' + '+'+ column , data=data).fit()
        print('Parameters:\n' + str(lmwhite.params))
        print('R Square : ' + str(lmwhite.rsquared))
        print('AIC: ' +  str(lmwhite.aic))
        print("\n")
# Out:
# Parameters, R^2 and AIC values for model with alcohol and fixed_acidity:
#
# Parameters:
# Intercept        3.084062
# alcohol          0.308083
# fixed_acidity   -0.064979
# dtype: float64
# R Square : 0.19350275804287065
# AIC: 11661.895001084189
#
#
# Parameters, R^2 and AIC values for model with alcohol and volatile_acidity:
#
# Parameters:
# Intercept           3.017282
# alcohol             0.324447
# volatile_acidity   -1.979194
# dtype: float64
# R Square : 0.240231184754771
# AIC: 11369.551595506142
#
#
# Parameters, R^2 and AIC values for model with alcohol and citric_acid:
#
# Parameters:
# Intercept      2.509822
# alcohol        0.314773
# citric_acid    0.175003
# dtype: float64
# R Square : 0.19029391204484647
# AIC: 11681.344222675325
#
#
# Parameters, R^2 and AIC values for model with alcohol and residual_sugar:
#
# Parameters:
# Intercept         2.021445
# alcohol           0.353637
# residual_sugar    0.021627
# dtype: float64
# R Square : 0.20195100081636752
# AIC: 11610.316711313095
#
#
# Parameters, R^2 and AIC values for model with alcohol and chlorides:
#
# Parameters:
# Intercept    2.861231
# alcohol      0.297669
# chlorides   -2.470822
# dtype: float64
# R Square : 0.1929586104259372
# AIC: 11665.198591189434
#
#
# Parameters, R^2 and AIC values for model with alcohol and free_sulfur_dioxide:
#
# Parameters:
# Intercept              2.115952
# alcohol                0.335952
# free_sulfur_dioxide    0.006505
# dtype: float64
# R Square : 0.20435197005199823
# AIC: 11595.558628693609
#
#
# Parameters, R^2 and AIC values for model with alcohol and total_sulfur_dioxide:
#
# Parameters:
# Intercept               2.418509
# alcohol                 0.321880
# total_sulfur_dioxide    0.000543
# dtype: float64
# R Square : 0.19026656977728362
# AIC: 11681.509616226653
#
#
# Parameters, R^2 and AIC values for model with alcohol and density:
#
# Parameters:
# Intercept   -22.491695
# alcohol       0.360356
# density      24.728423
# dtype: float64
# R Square : 0.1924548766221541
# AIC: 11668.254839004207
#
#
# Parameters, R^2 and AIC values for model with alcohol and pH:
#
# Parameters:
# Intercept    1.742207
# alcohol      0.309342
# pH           0.277016
# dtype: float64
# R Square : 0.19192320109710737
# AIC: 11671.478547199511
#
#
# Parameters, R^2 and AIC values for model with alcohol and sulphates:
#
# Parameters:
# Intercept    2.340943
# alcohol      0.314238
# sulphates    0.475621
# dtype: float64
# R Square : 0.193480628029444
# AIC: 11662.029398715105

# %%
#iteration 3
import pandas as pd
import statsmodels.formula.api as smf

data = pd.read_csv('winequality-white.csv')
data1 = data.iloc[:,data.columns!='quality']


for column in data1:
    if str(column) != 'alcohol' and str(column)!= 'volatile_acidity':
        print('Parameters, R^2 and AIC values for model with '+ 'alcohol, volatile_acidity' + ' and '+column +':\n')
        lmwhite = smf.ols(formula='quality'+ '~' + 'alcohol' + '+' + 'volatile_acidity' + '+'+ column , data=data).fit()
        print('Parameters:\n' + str(lmwhite.params))
        print('R Square : ' + str(lmwhite.rsquared))
        print('AIC: ' +  str(lmwhite.aic))
        print("\n")
# Out:
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity and fixed_acidity:
#
# Parameters:
# Intercept           3.548185
# alcohol             0.318817
# volatile_acidity   -1.987552
# fixed_acidity      -0.068476
# dtype: float64
# R Square : 0.24442512013342244
# AIC: 11344.439663077177
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity and citric_acid:
#
# Parameters:
# Intercept           3.046895
# alcohol             0.324021
# volatile_acidity   -1.990632
# citric_acid        -0.065692
# dtype: float64
# R Square : 0.2403096162423578
# AIC: 11371.04594530271
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity and residual_sugar:
#
# Parameters:
# Intercept           2.355675
# alcohol             0.374572
# volatile_acidity   -2.106709
# residual_sugar      0.026607
# dtype: float64
# R Square : 0.2585261580678476
# AIC: 11252.166211338426
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity and chlorides:
#
# Parameters:
# Intercept           3.178955
# alcohol             0.314744
# volatile_acidity   -1.948390
# chlorides          -1.490588
# dtype: float64
# R Square : 0.24139567575026155
# AIC: 11364.038714955468
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity and free_sulfur_dioxide:
#
# Parameters:
# Intercept              2.603746
# alcohol                0.343181
# volatile_acidity      -1.903987
# free_sulfur_dioxide    0.005541
# dtype: float64
# R Square : 0.25077123710588156
# AIC: 11303.12734255514
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity and total_sulfur_dioxide:
#
# Parameters:
# Intercept               2.649053
# alcohol                 0.344473
# volatile_acidity       -2.043505
# total_sulfur_dioxide    0.001269
# dtype: float64
# R Square : 0.24313806051250386
# AIC: 11352.775904914619
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity and density:
#
# Parameters:
# Intercept          -36.498611
# alcohol              0.398893
# volatile_acidity    -2.072116
# density             38.991887
# dtype: float64
# R Square : 0.24690635620080115
# AIC: 11328.32862871149
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity and pH:
#
# Parameters:
# Intercept           2.336563
# alcohol             0.321041
# volatile_acidity   -1.965689
# pH                  0.223561
# dtype: float64
# R Square : 0.2416603122613571
# AIC: 11362.329766392764
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity and sulphates:
#
# Parameters:
# Intercept           2.802988
# alcohol             0.325028
# volatile_acidity   -1.962858
# sulphates           0.415712
# dtype: float64
# R Square : 0.24309658826998537
# AIC: 11353.044283423538

# %%
#iteration 4
for column in datax:
    if str(column) != 'alcohol' and str(column)!= 'volatile_acidity' and str(column)!='residual_sugar':
        print('Parameters, R^2 and AIC values for model with '+ 'alcohol, volatile_acidity,residual_sugar' + ' and '+column +':\n')
        lmwhite = smf.ols(formula='quality'+ '~' + 'alcohol' + '+' + 'volatile_acidity' + '+' +'residual_sugar'+ '+' + column , data=data).fit()
        print('Parameters:\n' + str(lmwhite.params))
        print('R Square : ' + str(lmwhite.rsquared))
        print('AIC: ' +  str(lmwhite.aic))
        print("\n")
# Out:
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar and fixed_acidity:
#
# Parameters:
# Intercept           2.918716
# alcohol             0.369516
# volatile_acidity   -2.118500
# residual_sugar      0.027172
# fixed_acidity      -0.074432
# dtype: float64
# R Square : 0.26347319503670863
# AIC: 11221.377758083716
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar and citric_acid:
#
# Parameters:
# Intercept           2.415490
# alcohol             0.374228
# volatile_acidity   -2.134684
# residual_sugar      0.026946
# citric_acid        -0.151358
# dtype: float64
# R Square : 0.2589395618598682
# AIC: 11251.434602561458
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar and chlorides:
#
# Parameters:
# Intercept           2.464220
# alcohol             0.367897
# volatile_acidity   -2.086006
# residual_sugar      0.026198
# chlorides          -0.906807
# dtype: float64
# R Square : 0.2589527918820166
# AIC: 11251.347158645158
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar and free_sulfur_dioxide:
#
# Parameters:
# Intercept              2.133992
# alcohol                0.382052
# volatile_acidity      -2.034880
# residual_sugar         0.023224
# free_sulfur_dioxide    0.004097
# dtype: float64
# R Square : 0.2639942210749575
# AIC: 11217.91164036277
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar and total_sulfur_dioxide:
#
# Parameters:
# Intercept               2.225959
# alcohol                 0.381054
# volatile_acidity       -2.128880
# residual_sugar          0.025531
# total_sulfur_dioxide    0.000539
# dtype: float64
# R Square : 0.2590211914718852
# AIC: 11250.895046215752
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar and density:
#
# Parameters:
# Intercept           74.224822
# alcohol              0.286371
# volatile_acidity    -2.059334
# residual_sugar       0.052299
# density            -71.546483
# dtype: float64
# R Square : 0.263943222871599
# AIC: 11218.251013440533
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar and pH:
#
# Parameters:
# Intercept           1.228933
# alcohol             0.372589
# volatile_acidity   -2.093974
# residual_sugar      0.028427
# pH                  0.355183
# dtype: float64
# R Square : 0.2620479018797257
# AIC: 11230.84698554119
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar and sulphates:
#
# Parameters:
# Intercept           2.111974
# alcohol             0.375967
# volatile_acidity   -2.090835
# residual_sugar      0.027012
# sulphates           0.453258
# dtype: float64
# R Square : 0.2619283174277447
# AIC: 11231.640637587649

# %%
#iteration 5 
for column in datax:
    if str(column) != 'alcohol' and str(column)!= 'volatile_acidity' and str(column)!='residual_sugar' and str(column)!='free_sulfur_dioxide':
        print('Parameters, R^2 and AIC values for model with '+ 'alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide' + ' and '+column +':\n')
        lmwhite = smf.ols(formula='quality'+ '~' + 'alcohol' + '+' + 'volatile_acidity' + '+' +'residual_sugar'+ '+' + 'free_sulfur_dioxide'+ '+' + column , data=data).fit()
        print('Parameters:\n' + str(lmwhite.params))
        print('R Square : ' + str(lmwhite.rsquared))
        print('AIC: ' +  str(lmwhite.aic))
        print("\n")
# Out:
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide and fixed_acidity:
#
# Parameters:
# Intercept              2.663225
# alcohol                0.376845
# volatile_acidity      -2.051540
# residual_sugar         0.024017
# free_sulfur_dioxide    0.003757
# fixed_acidity         -0.067530
# dtype: float64
# R Square : 0.26802868608177377
# AIC: 11192.989068542449
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide and citric_acid:
#
# Parameters:
# Intercept              2.201120
# alcohol                0.381766
# volatile_acidity      -2.066782
# residual_sugar         0.023570
# free_sulfur_dioxide    0.004163
# citric_acid           -0.178806
# dtype: float64
# R Square : 0.26456976643526897
# AIC: 11216.079980277467
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide and chlorides:
#
# Parameters:
# Intercept              2.257130
# alcohol                0.374390
# volatile_acidity      -2.009712
# residual_sugar         0.022697
# free_sulfur_dioxide    0.004158
# chlorides             -1.055996
# dtype: float64
# R Square : 0.2645715966998127
# AIC: 11216.067790614215
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide and total_sulfur_dioxide:
#
# Parameters:
# Intercept               2.259743
# alcohol                 0.374906
# volatile_acidity       -1.987104
# residual_sugar          0.023898
# free_sulfur_dioxide     0.005079
# total_sulfur_dioxide   -0.000744
# dtype: float64
# R Square : 0.2646215694724575
# AIC: 11215.734957457775
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide and density:
#
# Parameters:
# Intercept              70.962195
# alcohol                 0.297280
# volatile_acidity       -1.992534
# residual_sugar          0.047968
# free_sulfur_dioxide     0.003925
# density               -68.509916
# dtype: float64
# R Square : 0.26895156456680847
# AIC: 11186.80971324494
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide and pH:
#
# Parameters:
# Intercept              1.104866
# alcohol                0.379862
# volatile_acidity      -2.026588
# residual_sugar         0.025066
# free_sulfur_dioxide    0.003900
# pH                     0.327779
# dtype: float64
# R Square : 0.2669807882016201
# AIC: 11199.9960827207
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide and sulphates:
#
# Parameters:
# Intercept              1.919333
# alcohol                0.382993
# volatile_acidity      -2.023558
# residual_sugar         0.023754
# free_sulfur_dioxide    0.003907
# sulphates              0.418361
# dtype: float64
# R Square : 0.2668809071959043
# AIC: 11200.663437451445

# %%
#iteration 6
for column in datax:
    if str(column) != 'alcohol' and str(column)!= 'volatile_acidity' and str(column)!='residual_sugar' and str(column)!='free_sulfur_dioxide' and str(column)!='density':
        print('Parameters, R^2 and AIC values for model with '+ 'alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide,density' + ' and '+column +':\n')
        lmwhite = smf.ols(formula='quality'+ '~' + 'alcohol' + '+' + 'volatile_acidity' + '+' +'residual_sugar'+ '+' + 'free_sulfur_dioxide'+ '+' + 'density'+ '+' + column , data=data).fit()
        print('Parameters:\n' + str(lmwhite.params))
        print('R Square : ' + str(lmwhite.rsquared))
        print('AIC: ' +  str(lmwhite.aic))
        print("\n")
# Out:
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide,density and fixed_acidity:
#
# Parameters:
# Intercept              52.887789
# alcohol                 0.316821
# volatile_acidity       -2.013794
# residual_sugar          0.041830
# free_sulfur_dioxide     0.003768
# density               -50.204599
# fixed_acidity          -0.040316
# dtype: float64
# R Square : 0.2700356043712042
# AIC: 11181.541292566602
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide,density and citric_acid:
#
# Parameters:
# Intercept              68.954283
# alcohol                 0.299661
# volatile_acidity       -2.008144
# residual_sugar          0.047391
# free_sulfur_dioxide     0.003960
# density               -66.481220
# citric_acid            -0.080466
# dtype: float64
# R Square : 0.2690637756869467
# AIC: 11188.057844798368
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide,density and chlorides:
#
# Parameters:
# Intercept              69.755086
# alcohol                 0.292755
# volatile_acidity       -1.973194
# residual_sugar          0.047076
# free_sulfur_dioxide     0.003977
# density               -67.210291
# chlorides              -0.845174
# dtype: float64
# R Square : 0.26931963102915335
# AIC: 11186.343059286646
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide,density and total_sulfur_dioxide:
#
# Parameters:
# Intercept               69.588211
# alcohol                  0.297605
# volatile_acidity        -1.984052
# residual_sugar           0.047597
# free_sulfur_dioxide      0.004121
# density                -67.117810
# total_sulfur_dioxide    -0.000145
# dtype: float64
# R Square : 0.26897350545797727
# AIC: 11188.662707803907
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide,density and pH:
#
# Parameters:
# Intercept              93.230611
# alcohol                 0.264626
# volatile_acidity       -1.965342
# residual_sugar          0.059317
# free_sulfur_dioxide     0.003567
# density               -92.223832
# pH                      0.495485
# dtype: float64
# R Square : 0.2751821150474081
# AIC: 11146.886327646025
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide,density and sulphates:
#
# Parameters:
# Intercept              91.952231
# alcohol                 0.272424
# volatile_acidity       -1.962752
# residual_sugar          0.056408
# free_sulfur_dioxide     0.003592
# density               -89.717556
# sulphates               0.616124
# dtype: float64
# R Square : 0.27473739103132
# AIC: 11149.890655072293

# %%
#iteration 7
for column in datax:
    if str(column) != 'alcohol' and str(column)!= 'volatile_acidity' and str(column)!='residual_sugar' and str(column)!='free_sulfur_dioxide' and str(column)!='density' and str(column)!='pH':
        print('Parameters, R^2 and AIC values for model with '+ 'alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide,density,pH' + ' and '+column +':\n')
        lmwhite = smf.ols(formula='quality'+ '~' + 'alcohol' + '+' + 'volatile_acidity' + '+' +'residual_sugar'+ '+' + 'free_sulfur_dioxide'+ '+' + 'density'+ '+' + 'pH' + '+' + column , data=data).fit()
        print('Parameters:\n' + str(lmwhite.params))
        print('R Square : ' + str(lmwhite.rsquared))
        print('AIC: ' +  str(lmwhite.aic))
        print("\n")
# Out:
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide,density,pH and fixed_acidity:
#
# Parameters:
# Intercept              120.929672
# alcohol                  0.231929
# volatile_acidity        -1.932440
# residual_sugar           0.069937
# free_sulfur_dioxide      0.003631
# density               -120.648814
# pH                       0.654264
# fixed_acidity            0.045867
# dtype: float64
# R Square : 0.27594541337094614
# AIC: 11143.725575947177
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide,density,pH and citric_acid:
#
# Parameters:
# Intercept              95.218996
# alcohol                 0.262126
# volatile_acidity       -1.953187
# residual_sugar          0.060001
# free_sulfur_dioxide     0.003534
# density               -94.260307
# pH                      0.506703
# citric_acid             0.059479
# dtype: float64
# R Square : 0.2752402328100171
# AIC: 11148.493577659863
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide,density,pH and chlorides:
#
# Parameters:
# Intercept              92.158483
# alcohol                 0.262227
# volatile_acidity       -1.953522
# residual_sugar          0.058597
# free_sulfur_dioxide     0.003605
# density               -91.073178
# pH                      0.488571
# chlorides              -0.533117
# dtype: float64
# R Square : 0.2753273484353129
# AIC: 11147.904806044586
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide,density,pH and total_sulfur_dioxide:
#
# Parameters:
# Intercept               91.747364
# alcohol                  0.264968
# volatile_acidity        -1.956132
# residual_sugar           0.058919
# free_sulfur_dioxide      0.003779
# density                -90.721395
# pH                       0.495645
# total_sulfur_dioxide    -0.000158
# dtype: float64
# R Square : 0.27520793272745236
# AIC: 11148.711860029165
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide,density,pH and sulphates:
#
# Parameters:
# Intercept              111.165677
# alcohol                  0.243814
# volatile_acidity        -1.939595
# residual_sugar           0.066366
# free_sulfur_dioxide      0.003283
# density               -110.262389
# pH                       0.461855
# sulphates                0.570816
# dtype: float64
# R Square : 0.28011958271778714
# AIC: 11115.406935069044

# %%
#iteration 8
for column in datax:
    if str(column) != 'alcohol' and str(column)!= 'volatile_acidity' and str(column)!='residual_sugar' and str(column)!='free_sulfur_dioxide' and str(column)!='density' and str(column)!='pH' and str(column)!='sulphates':
        print('Parameters, R^2 and AIC values for model with '+ 'alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide,density,pH,sulphates' + ' and '+column +':\n')
        lmwhite = smf.ols(formula='quality'+ '~' + 'alcohol' + '+' + 'volatile_acidity' + '+' +'residual_sugar'+ '+' + 'free_sulfur_dioxide'+ '+' + 'density'+ '+' + 'pH' + '+' + 'sulphates' + '+' + column , data=data).fit()
        print('Parameters:\n' + str(lmwhite.params))
        print('R Square : ' + str(lmwhite.rsquared))
        print('AIC: ' +  str(lmwhite.aic))
        print("\n")
# Out:
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide,density,pH,sulphates and fixed_acidity:
#
# Parameters:
# Intercept              154.106249
# alcohol                  0.193163
# volatile_acidity        -1.888140
# residual_sugar           0.082847
# free_sulfur_dioxide      0.003349
# density               -154.291277
# pH                       0.694213
# sulphates                0.628508
# fixed_acidity            0.068104
# dtype: float64
# R Square : 0.2817519637259577
# AIC: 11106.287753619032
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide,density,pH,sulphates and citric_acid:
#
# Parameters:
# Intercept              112.715128
# alcohol                  0.241863
# volatile_acidity        -1.929963
# residual_sugar           0.066897
# free_sulfur_dioxide      0.003257
# density               -111.849946
# pH                       0.470854
# sulphates                0.569725
# citric_acid              0.047375
# dtype: float64
# R Square : 0.28015643468196394
# AIC: 11117.156191283764
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide,density,pH,sulphates and chlorides:
#
# Parameters:
# Intercept              110.107062
# alcohol                  0.241488
# volatile_acidity        -1.928080
# residual_sugar           0.065658
# free_sulfur_dioxide      0.003320
# density               -109.127081
# pH                       0.455132
# sulphates                0.570418
# chlorides               -0.520184
# dtype: float64
# R Square : 0.28025785277681636
# AIC: 11116.466067972477
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide,density,pH,sulphates and total_sulfur_dioxide:
#
# Parameters:
# Intercept               108.270237
# alcohol                   0.244284
# volatile_acidity         -1.919991
# residual_sugar            0.065614
# free_sulfur_dioxide       0.003723
# density                -107.327962
# pH                        0.461792
# sulphates                 0.577588
# total_sulfur_dioxide     -0.000330
# dtype: float64
# R Square : 0.28023226172792537
# AIC: 11116.640217464252

# %%
#iteration 9
for column in datax:
    if str(column) != 'alcohol' and str(column)!= 'volatile_acidity' and str(column)!='residual_sugar' and str(column)!='free_sulfur_dioxide' and str(column)!='density' and str(column)!='pH' and str(column)!='sulphates' and str(column)!='fixed_acidity' :
        print('Parameters, R^2 and AIC values for model with '+ 'alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide,density,pH,sulphates,fixed_acidity' + ' and '+column +':\n')
        lmwhite = smf.ols(formula='quality'+ '~' + 'alcohol' + '+' + 'volatile_acidity' + '+' +'residual_sugar'+ '+' + 'free_sulfur_dioxide'+ '+' + 'density'+ '+' + 'pH' + '+' + 'sulphates' + '+' + 'fixed_acidity' + '+' + column , data=data).fit()
        print('Parameters:\n' + str(lmwhite.params))
        print('R Square : ' + str(lmwhite.rsquared))
        print('AIC: ' +  str(lmwhite.aic))
        print("\n")
# Out:
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide,density,pH,sulphates,fixed_acidity and citric_acid:
#
# Parameters:
# Intercept              154.371746
# alcohol                  0.192812
# volatile_acidity        -1.885455
# residual_sugar           0.082930
# free_sulfur_dioxide      0.003341
# density               -154.563148
# pH                       0.695837
# sulphates                0.627899
# fixed_acidity            0.067777
# citric_acid              0.014425
# dtype: float64
# R Square : 0.28175534262626656
# AIC: 11108.264711589254
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide,density,pH,sulphates,fixed_acidity and chlorides:
#
# Parameters:
# Intercept              152.695419
# alcohol                  0.193181
# volatile_acidity        -1.883946
# residual_sugar           0.082167
# free_sulfur_dioxide      0.003365
# density               -152.821734
# pH                       0.686122
# sulphates                0.627084
# fixed_acidity            0.066639
# chlorides               -0.239482
# dtype: float64
# R Square : 0.2817805149625292
# AIC: 11108.093048267649
#
#
# Parameters, R^2 and AIC values for model with alcohol, volatile_acidity,residual_sugar,free_sulfur_dioxide,density,pH,sulphates,fixed_acidity and total_sulfur_dioxide:
#
# Parameters:
# Intercept               151.255720
# alcohol                   0.193990
# volatile_acidity         -1.871694
# residual_sugar            0.082062
# free_sulfur_dioxide       0.003728
# density                -151.398111
# pH                        0.692221
# sulphates                 0.633856
# fixed_acidity             0.067536
# total_sulfur_dioxide     -0.000284
# dtype: float64
# R Square : 0.281835337454053
# AIC: 11107.719164214324

# %%
lmwhite_best = smf.ols(formula='quality'+ '~' + 'alcohol' + '+' + 'volatile_acidity' + 
                  '+' +'residual_sugar'+ '+' + 'free_sulfur_dioxide'+ '+'
                  + 'density'+ '+' + 'pH' + '+' + 'sulphates' + 
                  '+' + 'fixed_acidity' , data=data).fit()
act_tar = data.iloc[:,-1]
#print(actual)
pred_tar = lmwhite_best.predict(data.iloc[:,:-1])
#print(pred)
diff_tar = act_tar - pred_tar

abs_diff = np.abs(diff_tar)

sorted_abs_diff = sorted(abs_diff)
worst_five_wines = sort_abs_diff[-5:]

five_indices = []
for x in worst_five_wines:
    for i,y in enumerate(abs_diff):
        if x==y:
            five_indices.append(i)
            break
print('Values of the absolute difference for the five wines that have the largest magnitudes of difference between the predicted and the actual wine-quality values:\n')
print(five_wines)
print('\n')
print('Indices of them in the given data:\n')
print(five_indices)
print('\n')
five_samples=[]
for x in five_indices:
    five_samples.append(x+2)
print('Locations of them as per the excel file:\n')
print(five_samples)
# Out:
# Values of the absolute difference for the five wines that have the largest magnitudes of difference between the predicted and the actual wine-quality values:
#
# [3.2382586252074166, 3.353270875186028, 3.386702300327813, 3.4317797873340954, 3.824598915802026]
#
#
# Indices of them in the given data:
#
# [3810, 445, 253, 3307, 4745]
#
#
# Locations of them as per the excel file:
#
# [3812, 447, 255, 3309, 4747]
